# %%
from collections import deque

# %%
stack = deque()

# %%
stack
# Out:
# deque([])

# %%
stack.append(1)

# %%
stack
# Out:
# deque([1])

# %%
stack.append("https://foxnews.com")

# %%
stack
# Out:
# deque([1, 'https://foxnews.com'])

# %%
stack.append("https://espn.com")

# %%
stack
# Out:
# deque([1, 'https://foxnews.com', 'https://espn.com'])

# %%
stack.pop()
# Out:
# 'https://espn.com'

# %%
stack.popleft()
# Out:
# 1

# %%
stack
# Out:
# deque(['https://foxnews.com'])

# %%
type(stack)
# Out:
# collections.deque
